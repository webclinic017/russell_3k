# %%
import src.data.yahoo_fin_stock_info as si;

# %%
russell_1k_stocks = si.tickers_russell1000()

# %%
russell_2k_stocks = list(pd.read_csv("data/ticker_lists/russell_2k_stock_lst.csv")['Ticker'])

# %%
russell_3k_stocks = russell_1k_stocks + russell_2k_stocks

# %%
len(russell_3k_stocks)
# Out:
# 3047

# %%
finviz_lst = pd.read_csv("/home/gdp/russell_3k/data/finviz/2021-11/2021-11-15/finviz.csv")

# %%
finviz_lst.head()
# Out:
#   Ticker                          Company              Sector  \
# 0  A      Agilent Technologies, Inc.       Healthcare
# 1  AA     Alcoa Corporation                Basic Materials
# 2  AAAU   Goldman Sachs Physical Gold ETF  Financial
# 3  AAC    Ares Acquisition Corporation     Financial
# 4  AACG   ATA Creativity Global            Consumer Defensive
#
#                         Industry  Market Cap    P/E Dividend Yield  \
# 0  Diagnostics & Research        47,143.09   49.15   0.49%
# 1  Aluminum                      9,343.77    11.79   0.79%
# 2  Exchange Traded Fund          NaN         NaN     NaN
# 3  Shell Companies               1,228.72    101.44  NaN
# 4  Education & Training Services 67.74       NaN     NaN
#
#   EPS growth past 5 years Sales growth past 5 years  Shares Outstanding  \
# 0  12.00%                  5.70%                    303.0
# 1  28.00%                  -3.70%                   187.0
# 2  NaN                     NaN                      NaN
# 3  NaN                     NaN                      124.87
# 4  -36.60%                 -17.20%                  33.68
#
#   Insider Ownership Insider Transactions Institutional Ownership  \
# 0  0.10%             -25.37%              91.30%
# 1  0.10%             -17.99%              78.10%
# 2  NaN               NaN                  NaN
# 3  NaN               NaN                  59.30%
# 4  18.70%            0.00%                16.70%
#
#   Institutional Transactions Float Short Operating Margin Performance (Week)  \
# 0  1.16%                      1.53%       20.40%           -1.96%
# 1  -0.83%                     4.51%       12.60%           3.62%
# 2  NaN                        NaN         NaN              2.15%
# 3  0.82%                      0.08%       NaN              0.31%
# 4  0.08%                      0.16%       -51.50%          -6.73%
#
#   Performance (Month) Performance (Quarter) Performance (Half Year)  \
# 0  2.94%               -1.95%                22.55%
# 1  -9.59%              21.68%                27.08%
# 2  5.40%               4.36%                 -0.43%
# 3  1.03%               1.23%                 0.72%
# 4  -12.34%             -16.60%               -26.78%
#
#   Performance (Year) Performance (YTD)  Beta Volatility (Month)  \
# 0  43.22%             33.16%           0.99   1.99%
# 1  205.55%            119.65%          2.41   4.71%
# 2  -1.44%             -2.16%           NaN    0.69%
# 3  NaN                -0.30%           NaN    0.37%
# 4  90.59%             81.51%           1.68   6.33%
#
#   20-Day Simple Moving Average 50-Day Simple Moving Average  \
# 0  0.03%                        -2.50%
# 1  3.06%                        3.59%
# 2  3.29%                        4.46%
# 3  0.22%                        0.62%
# 4  -7.40%                       -11.17%
#
#   200-Day Simple Moving Average 52-Week High 52-Week Low  \
# 0  9.01%                         -12.13%      50.00%
# 1  32.65%                        -12.05%      219.23%
# 2  3.97%                         -4.68%       11.02%
# 3  0.58%                         -1.60%       3.58%
# 4  -34.17%                       -89.06%      96.35%
#
#    Relative Strength Index (14)  Analyst Recom  Price  Change   Volume  \
# 0 48.32                         NaN            157.78  -1.93%  1121270
# 1 54.77                         1.8            50.63   -2.48%  6345965
# 2 70.01                         NaN            18.53   -0.16%  271985
# 3 59.81                         NaN            9.84    -0.10%  103517
# 4 37.13                         1.0            2.16    -2.26%  11621
#
#    Target Price
# 0 175.88
# 1 58.85
# 2 NaN
# 3 NaN
# 4 30.5

# %%
russell_3k_df = finviz_lst[finviz_lst["Ticker"].isin(russell_3k_stocks)]

# %%
print(len(russell_3k_df))
russell_3k_df.head()
# Out:
# 2985
#    Ticker                       Company           Sector  \
# 0   A      Agilent Technologies, Inc.    Healthcare
# 1   AA     Alcoa Corporation             Basic Materials
# 10  AAL    American Airlines Group Inc.  Industrials
# 13  AAN    The Aaron's Company, Inc.     Industrials
# 15  AAON   AAON, Inc.                    Industrials
#
#                          Industry  Market Cap   P/E Dividend Yield  \
# 0   Diagnostics & Research        47,143.09   49.15  0.49%
# 1   Aluminum                      9,343.77    11.79  0.79%
# 10  Airlines                      13,831.82   NaN    NaN
# 13  Rental & Leasing Services     819.11      9.16   1.55%
# 15  Building Products & Equipment 3,981.79    57.53  0.50%
#
#    EPS growth past 5 years Sales growth past 5 years  Shares Outstanding  \
# 0   12.00%                  5.70%                    303.0
# 1   28.00%                  -3.70%                   187.0
# 10  -29.60%                 -15.80%                  648.56
# 13  -37.70%                 -4.00%                   32.48
# 15  12.10%                  7.50%                    52.42
#
#    Insider Ownership Insider Transactions Institutional Ownership  \
# 0   0.10%             -25.37%              91.30%
# 1   0.10%             -17.99%              78.10%
# 10  0.10%             0.00%                55.20%
# 13  1.30%             -13.76%              NaN
# 15  18.10%            -0.08%               72.10%
#
#    Institutional Transactions Float Short Operating Margin Performance (Week)  \
# 0   1.16%                      1.53%       20.40%           -1.96%
# 1   -0.83%                     4.51%       12.60%           3.62%
# 10  2.03%                      14.91%      -11.40%          -8.67%
# 13  3.30%                      2.14%       7.00%            -4.38%
# 15  0.28%                      3.14%       17.40%           2.59%
#
#    Performance (Month) Performance (Quarter) Performance (Half Year)  \
# 0   2.94%               -1.95%                22.55%
# 1   -9.59%              21.68%                27.08%
# 10  1.70%               5.07%                 -13.75%
# 13  -6.30%              -7.37%                -20.70%
# 15  9.64%               12.75%                15.34%
#
#    Performance (Year) Performance (YTD)  Beta Volatility (Month)  \
# 0   43.22%             33.16%           0.99   1.99%
# 1   205.55%            119.65%          2.41   4.71%
# 10  66.01%             28.85%           1.66   2.98%
# 13  NaN                35.81%           NaN    5.23%
# 15  17.91%             15.19%           0.58   2.42%
#
#    20-Day Simple Moving Average 50-Day Simple Moving Average  \
# 0   0.03%                        -2.50%
# 1   3.06%                        3.59%
# 10  0.51%                        0.46%
# 13  -3.07%                       -4.56%
# 15  5.60%                        11.12%
#
#    200-Day Simple Moving Average 52-Week High 52-Week Low  \
# 0   9.01%                         -12.13%      50.00%
# 1   32.65%                        -12.05%      219.23%
# 10  -3.86%                        -22.12%      71.48%
# 13  -7.61%                        -31.32%      58.95%
# 15  12.27%                        -5.54%       29.60%
#
#     Relative Strength Index (14)  Analyst Recom  Price  Change    Volume  \
# 0  48.32                         NaN            157.78  -1.93%  1121270
# 1  54.77                         1.8            50.63   -2.48%  6345965
# 10 48.41                         3.1            20.32   0.15%   20772892
# 13 46.22                         2.7            25.75   -1.98%  117088
# 15 71.35                         3.0            76.75   -0.95%  289982
#
#     Target Price
# 0  175.88
# 1  58.85
# 10 19.08
# 13 34.43
# 15 64.5
